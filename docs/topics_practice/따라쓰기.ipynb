# %% [markdown]
# 정보 이론과 MLE
#
# 정보 이론
#
# Iniformation Theory
#
# 정보 이란이란? 정보를 정량적으로 측정하는 이론.
# 얼마나 놀라운가?
# 얼마나 불확실한가? 를 숫자로 표현한다
# 머신러닝에서의 읨
# 손실 함수의 이론적 이론적 기반이다. CrossEntropyLoss
# 모델의 예측 불확실성 측정
# 두 확률 분포의 차이 측정 (KL 발산)
#
# 엔트로피 (Entorpy)
#
# 엔트로피란? 확률 분포의 불확실성의 양 또는 평균 정보량을 나타내는 지표
#
# 직관적 이해:
# 예측하기 어려울수록 엔트로피가 높다
# 확실한 사건은 엔트로피가 낮다
# 놀람의 정도를 측정하는 것이다.
