# %% [markdown]
# # 행렬 곱셈의 다양한 관점 이해
#
# ## 학습 목표
# - 열벡터 관점 vs 행벡터 관점
# - 내적 관점
# - 배치 처리 관점
# - 실제 신경망 레이어 연결

# %%
"""
스칼라: 0차원 텐서
벡터: 1차원 텐서
행렬: 2차원 텐서
텐서: 3차원 이상 (행렬의 배열의 배열)

중요: 텐서는 새로운 개념이 아니라, 벡터와 행렬을 다차원 배열이라는 이름으로 일반화 한것입니다.
"""

from typing import Any
from numpy._core.multiarray import scalar
from numpy.typing import NDArray
import numpy as np


# 스칼라
scalar: NDArray[Any] = np.array(3.14)
print(f"스칼라: {scalar}, shape: {scalar.shape}, 차원: {scalar.ndim}")

# 벡터 (1차원) 하나의 배열은 
vertor: NDArray[Any] = np.array([1, 2, 3])
print(f"벡터: {vertor}, shape: {vertor.shape}, 차원: {vertor.ndim}")

# 행렬 (2차원)
matrix: NDArray[Any] = np.array([[1, 0, 0], [1, 2, 3]])
print(f"행렬: {matrix}, shape: {matrix.shape}, 차원: {matrix.ndim}")

array_3d: NDArray[Any] = np.random.randn(2, 3, 4)
print(f"shape: {array_3d.shape}, ndim={array_3d.ndim}")

array_4d: NDArray[Any] = np.random.randn(2, 3, 4, 5)
print(f"shape: {array_4d.shape}, ndim={array_4d.ndim}")

"""
머신 러닝의 의미: 
배치, 시간, 채널, 높이, 너비 동영상? 

PyTorch에서 배열을 Tensor라고 부른다.

신경망의 가장 기본적인 계산은 행렬곱 과 편향이다. 

Wx + b 

여기에서 

x: 입력벡터

W: 가중치 행렬 

b: 편향 

출력 = 가중치 * 입력 + 편향 

핵심 요약

이번 단원에서 배운 내용

벡터와 행렬

벡터: 방향과 크기를 가진 화살표
행렬: 공간을 변환하는 함수 
행렬곱: 열벡터들의 선형결합으로 공간 변환
내적: 두 벡터의 정렬도 측정 ( 행렬아님. 열벡터, 행 백터! )

머신러닝 연결
다차원 매열: 벡터와 행렬을 일반화한 표현
기본 연산: 행렬곱 편향
내적의 의미: 두 벡터의 유사도 측정

핵심 직관

모든 데이터는 숫자 배열(벡터/행렬)로 표현한다
행렬은 공간을 변환하는 함수
신경망은 데이터를 더 잘 분리되는 공간으로 변환한다. 

다음 단원 미리보기 

다음 단원 (00a): 미적분 기초

선형대수로 구조를 이해했으니, 이제 미적분을 배웁니다.
미분: 함수의 변환율
Gradient: 손실을 줄이는 방향
Graient Descent: 학습 알고리즘의 수학적 ㅇ원리 

Calculus Foundations
Calculus
Derivative
Gradient
Gradient Descent

"""
# Out:
# 스칼라: 3.14, shape: (), 차원: 0
# 벡터: [1 2 3], shape: (3,), 차원: 1
# 행렬: [[1 0 0]
#  [1 2 3]], shape: (2, 3), 차원: 2
# shape: (2, 3, 4), ndim=3
# shape: (2, 3, 4, 5), ndim=4
