# %%
"""
Probability Distribution
Conditional Probability
Bayes' Theorem
Maximum Likelihood Estimation
Loss Function
CrossEntropy Loss
Multinomial Distribution
Mean Squared Error Loss
Normal Distribution
Batch Normalization

Probability and static foundations

직관적 이해 (Why)

확률이란 무엇인가? 

날씨 예보 

내일 해가 뜬다.
내이 비가 올 확률은 70% 
불확실한 사건이 일어날 가능성을 0~1 사이의 숫자로 표현 

머신러닝에서 확률

분류모델: 이 이미지가 고양이일 확률
예측의 불확실성: 호가률이 높을 수록 모델이 확신한다.
데이터의 패턴; 데이터가 따르는 확률 분포를 학습한다.

왜 딥러닝에 필요한가? 

손실 함수 (Loss Fucntion)의 의미: CrossEntorpy는 확률 분포 (Probability Distribution) 간의 차이

모델의 출력: Softmax는 확률 분포로 변환

학습의 목표: 
"""
