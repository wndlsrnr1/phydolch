# %%
f"""
확률과 통계 기초 (Probability & statistics Foundations) Part 2c: 정보 이론과 MLE 

아 파일은 Part 2c: 정보 이론과 MLE 입니다.

정보 이론과 MLE

최대 우도 추정 (Maximum Likelihood Estimation)

MLE가 뭔가요? 데이터를 가장 잘 설명하는 모델의 파라미터를 찾는 방법 
이 데이터가 나올 가능성이 가능 높은 파라미터는 뭐야? 를 차즌ㄴ 것

단계별 이해 MLE의 직관

Step1: 문제 상황

우리는데이터를 관측했습니다: x1, x2, x3, x3, ... xn
이 데이터를 생성한 롹률 분포는 무엇일까?
즉 분포의 파라미터는 무엇일까? 
우도 (Likelihood)의 개념
우도(Likelihood) 주어진 파라미터 에서 데이터가 나올 확률
L(쎼타|x) = P(x1, x2, ..., xn | 쎄타)
의미: 이 파라미터가 맞다면, 이 데이터가 나올 확률은

Step 3: MLE의 아이디어
직관: 이 데이터를 가장 잘 설명하는 파라미터를 찾자!
MLE arg max L(쎄타 | x)
비유: 시험 점수[85, 90, 88, 92]르리 본다면, 평균이 약 89인 정규분포가 가ㅓ장 그럴듯 함
Step4: 로그 우도(Log-Likelihood)로 변환
왜 로그를 쓰나? 
확률은 곱셉: P(x1, x2) = P(x1) * P(x2)

왜 로그를 쓰나?
확률은 곱세이다
곱센은 작은 값이면 0에 가까워진다 (수치가 불안정하다.
로그를 취하면 덧셈으로 변환할 수 있다. 

곱셉 -> 덧셈 (계산 안정)
작은 값도 안정적으로 계싼할수 있다
손실 함수 (Loss Function) 과의 연결
핵심 통찰: 손실 함수를 최소화: 로그 우도(Log-Likelihood)를 최대화
Loss = -logL(쎄타|x)
이것이 음의 로그 우도 (Negative Log-Likelihood, NLL)입니다.
이것이 음의 로그 우도 (Negative Log-Likelihood, NLL)입니다.
이유 최대 문제를 최소화 문제로 변환한다 (최적화 알고리즘과 호환)
경사 하강법(Gradient Descent)는 최소화 문제를 해결한다
MSE Loss의 완전한 유도 과정
목표: 오차가 정규 분포를 따른다는 가정에서 MSE Loss가 어떻게 나오는지 단계별로 보여드립니다.
독립 가정 (Independence Assumption)
데이터 포인트들이 서로 독립이라고 가정:
직관적 이해:
비유: 동전을 3번 던질때
동전 던지기는 서로 독립(첫번째 결과가 두번째 결과에 영향이 없다)
앞면이 나올 확률 1/2
전체 확률 = 각 시행 확률의 곱:

앞앞앞 앞앞앞

독립 가정: 데이터 포인트들이 서로 영향을 주지 않는다.
y1의 값이 y2의 확률에 영향을 주지 않는다.
각 데이터는 독립적으로 발생

공식의 의미: 

왜 곱셈인가? 

독립 사건이 동시에 일어날 확률 = 각 확률의 곱

동전을 3번 던져 모두 앞면이 나올 확률 
마찬가지로 ㅁ도ㅡㄴ 데이터가 동시에 나올 화귤ㄹ = 각 데이터 확률의 곱

기호 설명;
파이 곱하기 기호 (시그마는 합이었다면 파이는곱이다.)

쌔타 모델의 파라미터 (가중치, 편향 등)

가 주어졌을 대 모델 파라미터 쎄타에서 yi가 나올 확률

쎄타란 그렇다면 전체 화귤ㄹ범위인가? 아니면 전체 카테고리에서 yi가 나올 확률인가? 

Step2: 정규 분포 가정( Normal Distribution Assumtion )
회귀 모델: yi = f(xi;0) + ei, 여기서 오차 ei ~ N(0, )

각 데이터 포인트들의 확률 밀도 함수

의미 모델이 를 예측할때 시제값 yi가 나올 확률

Step3: 우도 함수(Likelihood Function) 계싼

모든 데이터에 대한 우도:


"""
